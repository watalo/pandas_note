# %%
import numpy as np
import pandas as pd
# 使用 Series 生产序列，Pandas默认生成整数索引
s = pd.Series([1,3,4, np.nan, 6,8]) 
s
# Out:
# 0    1.0
# 1    3.0
# 2    4.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
# 使用含日期时间索引和标签的Numpy数组生成DateFrame
dates = pd.date_range('20200703', periods = 6)
dates
df = pd.DataFrame(np.random.randn(6,5),index = dates, columns = list('ABCDE'))
df
# Out:
#                    A         B         C         D         E
# 2020-07-03 -1.446028  0.540743  2.399590  0.051693  0.590976
# 2020-07-04  0.014685 -0.295886  0.858854 -0.207670 -1.020108
# 2020-07-05 -1.125164 -0.007207 -1.116233  2.199565  0.727150
# 2020-07-06 -1.216120 -0.485737  0.462729  0.699238  0.220156
# 2020-07-07 -0.209744 -0.039157  0.348150  0.189432 -2.010233
# 2020-07-08 -1.403128 -1.020832 -0.219732  0.070998  0.187634

# %%
import pandas as pd
import numpy as np
# 使用Series字典对象生成DataFrame
df2 = pd.DataFrame({"A": 1.,
                    "N": pd.Timestamp('20200703'),
                    "B": pd.Series(1, index = list(range(4)),dtype='float32'),
                    "D": np.array([3]*4,dtype = 'int32'),
                    "E": pd.Categorical(["test","train","test","train"]),
                    "F": 'foo'})
df2
# Out:
#      A          N    B  D      E    F
# 0  1.0 2020-07-03  1.0  3   test  foo
# 1  1.0 2020-07-03  1.0  3  train  foo
# 2  1.0 2020-07-03  1.0  3   test  foo
# 3  1.0 2020-07-03  1.0  3  train  foo

# %%
#查询数据类型
df2.dtypes
# Out:
# A           float64
# N    datetime64[ns]
# B           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
# 获取单列数据
df2.A
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# Name: A, dtype: float64

# %%
df2.append
# Out:
# <bound method DataFrame.append of      A          N    B  D      E    F
# 0  1.0 2020-07-03  1.0  3   test  foo
# 1  1.0 2020-07-03  1.0  3  train  foo
# 2  1.0 2020-07-03  1.0  3   test  foo
# 3  1.0 2020-07-03  1.0  3  train  foo>

# %%
df.head() #Series 或着 DataFrame 前5位
# Out:
#                    A         B         C         D         E
# 2020-07-03 -1.446028  0.540743  2.399590  0.051693  0.590976
# 2020-07-04  0.014685 -0.295886  0.858854 -0.207670 -1.020108
# 2020-07-05 -1.125164 -0.007207 -1.116233  2.199565  0.727150
# 2020-07-06 -1.216120 -0.485737  0.462729  0.699238  0.220156
# 2020-07-07 -0.209744 -0.039157  0.348150  0.189432 -2.010233

# %%
df.tail(3) #Series或DataFrame 的尾部数据 可选数量
# Out:
#                    A         B         C         D         E
# 2020-07-06 -1.216120 -0.485737  0.462729  0.699238  0.220156
# 2020-07-07 -0.209744 -0.039157  0.348150  0.189432 -2.010233
# 2020-07-08 -1.403128 -1.020832 -0.219732  0.070998  0.187634

# %%
ts = pd.Series(np.random.randn(1000),
               index = pd.date_range('1/1/